# %%
import cv2
import matplotlib.pyplot as plt

# %%
# defining the imshow function
def imshow(title = 'Image',image = None,size = 10):
    w,h = image.shape[1],image.shape[0]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# loading our input image

image = cv2.imread('C:\\Users\\abhin\\OneDrive\\Documents\\GitHub\\Computer-Vision\\data\\apple.jpg')
imshow('apple',image,size=5)

# %%
# gray image

gray_image = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
imshow('gray apple',gray_image,size=5)

# %%
# Generally RGB has 3 dimensions but grayscale has only 1 dimension that is intensity of the pixel

print('RGB image shape:',image.shape)
print('Gray image shape:',gray_image.shape)
# Out:
# RGB image shape: (512, 512, 3)
# Gray image shape: (512, 512)
