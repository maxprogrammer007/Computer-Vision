# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.11.0

# %%
# loading images from the disk

Image = cv2.imread('C:\\Users\\abhin\\OneDrive\\Documents\\GitHub\\Computer-Vision\\data\\apple.jpg')  # read the image

# %%
# displaying the image
import matplotlib.pyplot as plt

plt.imshow(cv2.cvtColor(Image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# creating a simple function to display the image

def imshow(title="", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
imshow("Apple", Image)

# %%
# saving the image
cv2.imwrite('C:\\Users\\abhin\\OneDrive\\Documents\\GitHub\\Computer-Vision\\Results\\apple_copy.jpg', Image)
# Out:
# True

# %%
# printing the shape of the image
print(Image.shape)
# Out:
# (512, 512, 3)
