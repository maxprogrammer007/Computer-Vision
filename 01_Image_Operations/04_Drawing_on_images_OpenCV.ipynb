# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
# defining our imshow function

def imshow(title = 'Image',image = None,size = 10):
    w,h = image.shape[1],image.shape[0]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# creating a blank image
image = np.zeros((512,512,3),dtype=np.uint8)
image_gray = np.zeros((512,512),dtype=np.uint8)

imshow('RGB black Image',image)
imshow('Black Image Grayscale',image_gray)

# %%
# drawing a diagonal line  cv2.line(image,start,end,color,thickness)

cv2.line(image,(0,0),(511,511),(255,0,0),5)
imshow('Diagonal Line',image)

# %%
# creating a rectanle over the image cv2.rectangle(image,pt1,pt2,color,thickness)
cv2.rectangle(image,(100,100),(300,300),(0,255,0),3)
imshow('Rectangle',image)

# %%
# creating a circle over the image , cv2.circle(image,center,radius,color,thickness) 
cv2.circle(image,(256,256),100,(0,0,255),3)
imshow('Circle',image)
