# %%
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib as mpl
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
import cv2

# %%
# defining the imshow function
def imshow(title = 'Image',image = None,size = 10):
    w,h = image.shape[1],image.shape[0]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Translations 
# This is affine transformation that simply shifts the position of the image ( left or right )
# we use cv2.warpAffine() function to implement these transformations  
# cv2.warpAffine(image , T , ( width , height)

# %%
# load the image 


Image = cv2.imread('C:\\Users\\abhin\\OneDrive\\Documents\\GitHub\\Computer-Vision\\data\\apple.jpg')  # read the image
imshow('Original Image',Image)  # display the image

# %%
# store the height and width 

h,w = Image.shape[:2]   # get the height and width of the image
quarter_height , quarter_width = h/4 , w/4  # get the quarter height and width of the image

# our translation
#      | 1 0 Tx |
# T  = | 0 1 Ty |
#      | 0 0 1  |

# %%
# T is our translation matrix
# we use numpy to create the matrix

T = np.float32([[1,0,quarter_width],[0,1,quarter_height]])  # create the translation matrix

# we use warpaffine to transform the image using the matrix

Image_translation = cv2.warpAffine(Image,T,(w,h))  # apply the translation matrix to the image
imshow('Translation Image',Image_translation)  # display the image

# %%
# Rotations 
# This is an affine transformation that rotates the image at a particular angle
# we use cv2.getRotationMatrix2D() function to implement these transformations
# cv2.getRotationMatrix2D(center , angle , scale)

image = cv2.imread('C:\\Users\\abhin\\OneDrive\\Documents\\GitHub\\Computer-Vision\\data\\apple.jpg')  # read the image
height , width = image.shape[:2]  # get the height and width of the image   

# divide by 2 to rotate  the image around the centre 

rotation_matrix = cv2.getRotationMatrix2D((width/2,height/2),45,0.6)  # get the rotation matrix

# input our image and rotation matrix to get the rotated image

rotated_image = cv2.warpAffine(image,rotation_matrix,(width,height))  # apply the rotation matrix to the image

imshow('Rotated Image',rotated_image)  # display the image

# %%
# rotation with transpose

rotated_image = cv2.transpose(image)  # rotate the image using transpose
imshow('Rotated Image',rotated_image)  # display the image
