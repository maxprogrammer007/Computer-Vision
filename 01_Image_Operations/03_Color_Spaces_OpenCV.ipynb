# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# we will see the following things in our notebook :- 
# view individual channel of RGB image
# Manipulate color space 
# HSV color space

# %%
# defining our imshow function

def imshow(title = 'Image',image = None,size = 10):
    w,h = image.shape[1],image.shape[0]
    aspect_ratio = w/h
    plt.figure(figsize=(size*aspect_ratio,size))
    plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
 # reading the image
img = cv2.imread('C:\\Users\\abhin\\OneDrive\\Documents\\GitHub\\Computer-Vision\\data\\aero3.jpg') 
imshow('Original Image',img)

# %%
# using cv2.split() to split the image into its channels
b,g,r = cv2.split(img)
print(b.shape,g.shape,r.shape)
# Out:
# (480, 640) (480, 640) (480, 640)

# %%
# showing the individual channels
imshow('Blue Channel',b)

# %%
imshow('Green Channel',g)

# %%
imshow('Red Channel',r)
